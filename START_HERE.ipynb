# %% [markdown]
# # Full End-to-End Pipeline

# %%
# ── Google Colab Setup ────────────────────────────────────────────────────────
# This cell is a no-op when running locally.
import sys, os
from pathlib import Path

from js2py_.base import false

_root = next((p for p in [Path(os.getcwd()), *Path(os.getcwd()).parents]
              if p.name == 'cryptoTrading2'), None)
if _root:
    os.chdir(str(_root))
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from tqdm import tqdm
from files.functions import *
import datetime as dt

# %% [markdown]
# # Set up the Data

# %%
with open('files/coins.txt') as f:
    myCoins = [line.strip().upper() for line in f if line.strip()]
myCoins
# Out:
# ['BTC',
#  'AVAX',
#  'ETH',
#  'LTC',
#  'SOL',
#  'ICP',
#  'DOGE',
#  'USDT',
#  'XRP',
#  'ADA',
#  'DOT',
#  'LINK',
#  'BCH',
#  'ATOM',
#  'UNI',
#  'NEAR',
#  'XLM',
#  'MATIC',
#  'FIL',
#  'APT']

# %%
for myCoin in tqdm(myCoins):
    if refetch(fullDataPath(myCoin)):
        coinbase_market_analysis_gradient(myCoin, dataPath='data', plotPath='plots')
        cn = newspaper_sentiment_pipeline(myCoin, newspaper_path=f'newspapers/{myCoin}_newspapers.csv', queries_path='files/queries.txt')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved BTC Data
#   5%|▌         | 1/20 [00:52<16:46, 52.98s/it]
# Saved AVAX Data
#  10%|█         | 2/20 [01:37<14:19, 47.76s/it]
# Saved ETH Data
#  15%|█▌        | 3/20 [02:14<12:10, 42.97s/it]
# Saved LTC Data
#  20%|██        | 4/20 [03:02<11:58, 44.92s/it]
# Saved SOL Data
#  25%|██▌       | 5/20 [03:48<11:22, 45.51s/it]
# Saved ICP Data
#  30%|███       | 6/20 [04:42<11:14, 48.16s/it]
# Saved DOGE Data
#  35%|███▌      | 7/20 [05:31<10:30, 48.53s/it]
# Saved USDT Data
#  40%|████      | 8/20 [06:24<10:00, 50.06s/it]
# Saved XRP Data
#  45%|████▌     | 9/20 [07:11<08:58, 48.93s/it]
# Saved ADA Data
#  50%|█████     | 10/20 [08:03<08:19, 49.91s/it]
# Saved DOT Data
#  55%|█████▌    | 11/20 [08:37<06:45, 45.04s/it]
# Saved LINK Data
#  60%|██████    | 12/20 [09:14<05:41, 42.72s/it]
# Saved BCH Data
#  65%|██████▌   | 13/20 [10:05<05:16, 45.17s/it]
# Saved ATOM Data
#  70%|███████   | 14/20 [10:33<03:59, 39.91s/it]
# Saved UNI Data
# ...

# %% [markdown]
# ## Train Models

# %%
from files.functions import train_all_models
import warnings
warnings.filterwarnings('ignore')

for myCoin in tqdm(myCoins):
    train_all_models(myCoin, number=LIMIT)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# ...
#   Training all models for BTC
# ...
#
# [GBM] starting...
# [GBM] done  —  std_rmse = 0.2109
#
# [SVM] starting...
# [SVM] done  —  std_rmse = 0.1314
#
# [KNN] starting...
# [KNN] done  —  std_rmse = 0.5564
#
# [ARIMA] starting...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
# ...

# %% [markdown]
# ## Run Predictions

# %%
predictions_individual = predict_matrix('ICP')
predictions_individual.index = predictions_individual.index.str.upper()
predictions_individual
# Out:
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICP_prophet_model.pkl'
#              2026-05-31  2026-06-01  2026-06-02  2026-06-03  2026-06-04  \
# Model
# GBM            2.944260    3.061284    3.095425    3.178942    3.199847
# SVM            2.554025    2.453043    2.391774    2.354600    2.332046
# KNN            3.009008    3.009801    3.009806    3.009806    3.009806
# ARIMA          2.708715    2.709202    2.709243    2.709247    2.709247
# LSTM           2.573983    2.563015    2.559761    2.560034    2.561730
# TFT            2.622855    2.621474    2.620962    2.620089    2.617623
# TRANSFORMER    2.558052    2.550444    2.551472    2.551105    2.542681
#
#              2026-06-05  2026-06-06
# Model
# GBM            3.211025    3.211025
# SVM            2.318361    2.310058
# KNN            3.009806    3.009806
# ARIMA          2.709247    2.709247
# LSTM           2.563921    2.565945
# ...

# %%
for coin in tqdm(myCoins):
    predictions = predict_matrix(coin).T
    if not os.path.exists(f'predictions/{coin}'):
        os.mkdir(f'predictions/{coin}')
    predictions.to_csv(f'predictions/{coin}/{coin}_predictions.csv')
# Out:
#  40%|████      | 8/20 [00:01<00:01,  7.95it/s]
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICP_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/DOGE/DOGE_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/USDT/USDT_prophet_model.pkl'
#  55%|█████▌    | 11/20 [00:01<00:00,  9.09it/s]
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/XRP/XRP_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ADA/ADA_prophet_model.pkl'
# ...

# %% [markdown]
# ## Portfolio Optimizer

# %% [markdown]
# Compute Ranking based on Standardized RMSE

# %%
rmses = {}
for myCoin in tqdm(myCoins):
    errors = os.listdir(os.path.join('metrics', myCoin))
    predictions = predict_matrix(myCoin)
    for model_rmse in errors:
        model_name = model_rmse.split('_')[0].upper()
        file_path = os.path.join('metrics', myCoin, model_rmse)
        with open(file_path) as f:
            rmses[model_name] = float(f.read())
    rmses = pd.Series(rmses)
    ranks = rmses.rank().sort_values()

    # Compute weighted average
    weighted = pd.concat([predictions_individual, ranks], axis=1).dropna()
    weighted.columns = [*predictions_individual.columns, 'rank']

    # rank 1 = best model (lowest RMSE) → highest weight
    weighted['weight'] = 1 / weighted['rank']
    weighted['weight'] /= weighted['weight'].sum()

    date_cols = predictions_individual.columns
    final_predictions = weighted[date_cols].astype(float).multiply(weighted['weight'], axis=0).sum()
    final_predictions = final_predictions.to_frame(name=RESPONSE)
    final_predictions.to_csv(f'predictions/{myCoin}/{myCoin}_final_predictions.csv')
# Out:
#  40%|████      | 8/20 [00:00<00:01, 10.54it/s]
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICP_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/DOGE/DOGE_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/USDT/USDT_prophet_model.pkl'
#  50%|█████     | 10/20 [00:00<00:00, 10.97it/s]
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/XRP/XRP_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ADA/ADA_prophet_model.pkl'
# ...

# %% [markdown]
# ### Portfolio Optimization
#
# **Method:**
# 1. **Ensemble forecast** — for each coin, average the `m` model predictions weighted by `1 / RMSE` (better-calibrated models carry more weight).
# 2. **Daily expected returns** — compare each day's ensemble price to the previous day (or to today's closing price for day 0).
# 3. **Allocation** — solve the long-only max-return problem each day:
#
# $$\max_{\mathbf{w}} \sum_i w_i r_i \quad \text{s.t.} \quad \sum_i w_i \le 1,\; w_i \ge 0$$
#
#    The closed-form solution is *proportional to positive expected returns*: coins with a negative forecast get 0 weight and the corresponding capital stays in cash.
# 4. **Simulation** — compound the portfolio value day-by-day using the weighted return.
#
# > To add more coins, extend `myCoins` at the top of the notebook.

# %%
import numpy as np

# ─────────────────────────────────────────────────────────────────────────────
# USER PARAMETERS
# ─────────────────────────────────────────────────────────────────────────────
PRINCIPAL       = 390
COINS_PORTFOLIO = myCoins
# ─────────────────────────────────────────────────────────────────────────────

def _allocate(returns_row):
    pos = np.maximum(returns_row, 0.0)
    total = pos.sum()
    return pos / total if total > 0 else np.zeros(len(returns_row))

def _run_simulation(ensemble_df, current_prices, coins, principal):
    # Use date window with maximum coin coverage — handles stale/misaligned predictions
    date_coverage = ensemble_df.notna().sum(axis=1)
    peak_dates    = date_coverage[date_coverage == date_coverage.max()].index
    active_coins  = [c for c in coins if ensemble_df.loc[peak_dates, c].notna().all()]
    ens           = ensemble_df.loc[peak_dates, active_coins]

    opt_days, opt_returns = {}, {}
    for coin in active_coins:
        cp                = current_prices[coin]
        returns           = (ens[coin] - cp) / cp if cp != 0 else ens[coin] * 0
        best_idx          = int(returns.values.argmax())
        opt_days[coin]    = best_idx
        opt_returns[coin] = float(returns.iloc[best_idx])

    alloc_w  = _allocate(np.array([opt_returns.get(c, 0.0) for c in coins]))
    cash     = principal * float(1 - alloc_w.sum())
    holdings = {c: principal * float(w) for c, w in zip(coins, alloc_w)}
    bp       = {c: current_prices[c] for c in active_coins}
    prev_val = principal
    log      = []

    for i, date in enumerate(ens.index):
        coin_vals = {c: 0.0 for c in coins}
        for coin in active_coins:
            if holdings[coin] > 0:
                pred = float(ens[coin].iloc[i])
                cr   = (pred - bp[coin]) / bp[coin] if bp[coin] != 0 else 0.0
                coin_vals[coin] = holdings[coin] * (1 + cr)

        pv        = cash + sum(coin_vals[c] for c in active_coins)
        daily_ret = (pv - prev_val) / prev_val if prev_val != 0 else 0.0
        prev_val  = pv

        row = {
            'date': date,
            'portfolio_value': round(pv, 2),
            'daily_return_%': round(daily_ret * 100, 4),
            'cumulative_return_%': round((pv - principal) / principal * 100, 4),
        }
        for coin in coins:
            row[f'{coin}_$'] = round(coin_vals[coin], 2)
        row['cash_$'] = round(cash, 2)
        log.append(row)

        for coin in active_coins:
            if i == opt_days[coin] and holdings[coin] > 0:
                cash += coin_vals[coin]
                holdings[coin] = 0.0

    return pd.DataFrame(log).set_index('date')

# ── Collect per-coin matrices and RMSEs ───────────────────────────────────────
coin_matrices, coin_rmse_dicts, current_prices = {}, {}, {}

for coin in COINS_PORTFOLIO:
    matrix = predict_matrix(coin)
    matrix.index = matrix.index.str.upper()
    coin_matrices[coin] = matrix

    rmses = {}
    for fname in os.listdir(f'metrics/{coin}'):
        tag = fname.split('_')[0].upper()
        with open(f'metrics/{coin}/{fname}') as fh:
            rmses[tag] = float(fh.read())
    coin_rmse_dicts[coin] = rmses

    raw   = pd.read_csv(fullDataPath(coin))
    daily = dataSetup(raw, trainingColPath=TRAINING_COLUMNS, response=RESPONSE_VARIABLE, number=LIMIT)
    current_prices[coin] = float(daily[RESPONSE_VARIABLE].iloc[-1])

max_n = max(
    len(set(coin_rmse_dicts[c]) & set(coin_matrices[c].index))
    for c in COINS_PORTFOLIO
)

def _build_ensemble(n):
    ens = {}
    for coin in COINS_PORTFOLIO:
        matrix     = coin_matrices[coin]
        available  = {m: v for m, v in coin_rmse_dicts[coin].items() if m in matrix.index}
        top_models = sorted(available, key=available.get)[:n]
        if not top_models:
            ens[coin] = matrix.astype(float).mean(axis=0)
            continue
        sub = matrix.loc[top_models].astype(float)
        w   = 1 / pd.Series({m: available[m] for m in top_models})
        w  /= w.sum()
        ens[coin] = sub.multiply(w.values, axis=0).sum(axis=0)
    return pd.DataFrame(ens)

# ── Run all top-N simulations ─────────────────────────────────────────────────
simulation_dfs = {}   # top_n → result DataFrame
comparison      = []

for n in range(1, max_n + 1):
    df = _run_simulation(_build_ensemble(n), current_prices, COINS_PORTFOLIO, PRINCIPAL)
    simulation_dfs[n] = df
    final_pv = df['portfolio_value'].iloc[-1]
    comparison.append({
        'top_n': n,
        'portfolio_value': round(final_pv, 2),
        'total_return_%': round((final_pv - PRINCIPAL) / PRINCIPAL * 100, 4),
    })

# result_df = full ensemble (used by chart cell)
result_df = simulation_dfs[max_n]

# ── Summary comparison table ──────────────────────────────────────────────────
best = max(comparison, key=lambda x: x['portfolio_value'])

print(f"Principal: ${PRINCIPAL:,.2f}\n")
print(f"{'Top-N':>6}  {'Final Portfolio':>16}  {'Total Return':>12}")
print("─" * 40)
for r in comparison:
    marker = "  ◀ best" if r['top_n'] == best['top_n'] else ""
    print(f"  Top-{r['top_n']:<3}  ${r['portfolio_value']:>14,.2f}  {r['total_return_%']:>+11.4f}%{marker}")

# ── Per-N allocation DataFrames ───────────────────────────────────────────────
alloc_cols = [f'{c}_$' for c in COINS_PORTFOLIO] + ['cash_$']

for n, df in simulation_dfs.items():
    final_pv = df['portfolio_value'].iloc[-1]
    ret_pct  = (final_pv - PRINCIPAL) / PRINCIPAL * 100
    print(f"\n{'─'*60}")
    print(f"Top-{n} Ensemble  |  Final: ${final_pv:,.2f}  ({ret_pct:+.4f}%)")
    print(f"{'─'*60}")
    display_cols = ['portfolio_value', 'cumulative_return_%'] + [c for c in alloc_cols if c in df.columns]
# Out:
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICP_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/DOGE/DOGE_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/USDT/USDT_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/XRP/XRP_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ADA/ADA_prophet_model.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/DOT/DOT_prophet_model.pkl'
# ...

# %%
os.makedirs('files/simulations', exist_ok=True)

for n, df in simulation_dfs.items():
    df.to_csv(f'files/simulations/top_{n}_simulation.csv')

print(f"Wrote {len(simulation_dfs)} simulation CSVs to files/simulations/")
# Out:
# Wrote 8 simulation CSVs to files/simulations/

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

fig, (ax_val, ax_alloc) = plt.subplots(
    2, 1, figsize=(13, 9), gridspec_kw={'height_ratios': [3, 2]}
)

# ── Portfolio value over time ─────────────────────────────────────────────────
pv_series   = [PRINCIPAL] + result_df['portfolio_value'].tolist()
date_labels = ['Now'] + result_df.index.tolist()
x           = range(len(pv_series))

ax_val.plot(x, pv_series, marker='o', linewidth=2.5, color='#2196F3', zorder=3)
ax_val.fill_between(x, PRINCIPAL, pv_series,
                    where=[v >= PRINCIPAL for v in pv_series],
                    color='#4CAF50', alpha=0.25, label='Gain')
ax_val.fill_between(x, PRINCIPAL, pv_series,
                    where=[v < PRINCIPAL for v in pv_series],
                    color='#F44336', alpha=0.25, label='Loss')
ax_val.axhline(PRINCIPAL, color='gray', linestyle='--', alpha=0.7,
               label=f'Principal ${PRINCIPAL:,.0f}')
for i, v in enumerate(pv_series):
    ax_val.annotate(f'${v:,.0f}', (i, v),
                    textcoords='offset points', xytext=(0, 10),
                    ha='center', fontsize=8)
ax_val.set_xticks(list(x))
ax_val.set_xticklabels(date_labels, rotation=20, ha='right')
ax_val.yaxis.set_major_formatter(mtick.StrMethodFormatter('${x:,.0f}'))
ax_val.set_ylabel('Portfolio Value (USD)')
ax_val.set_title(
    f'Portfolio Optimization  —  {", ".join(COINS_PORTFOLIO)}  |  Principal: ${PRINCIPAL:,.0f}',
    fontsize=13, pad=10
)
ax_val.legend()
ax_val.grid(True, alpha=0.3)

# ── Daily allocation stacked bar ──────────────────────────────────────────────
alloc_cols = [f'{c}_$' for c in COINS_PORTFOLIO] + ['cash_$']
bar_labels = COINS_PORTFOLIO + ['Cash']
bar_colors = ['#FF9800', '#4CAF50', '#2196F3', '#9C27B0', '#00BCD4', '#F44336', '#795548']
x_pos      = range(len(result_df))
bottom     = np.zeros(len(result_df))

for idx, (col, label) in enumerate(zip(alloc_cols, bar_labels)):
    vals = result_df[col].values
    ax_alloc.bar(x_pos, vals, bottom=bottom, label=label,
                 color=bar_colors[idx % len(bar_colors)], alpha=0.85)
    for j, (v, b) in enumerate(zip(vals, bottom)):
        if v > 5:
            ax_alloc.text(j, b + v / 2, f'${v:,.0f}',
                          ha='center', va='center',
                          fontsize=9, fontweight='bold', color='white')
    bottom += vals

ax_alloc.set_xticks(list(x_pos))
ax_alloc.set_xticklabels(result_df.index.tolist(), rotation=20, ha='right')
ax_alloc.yaxis.set_major_formatter(mtick.StrMethodFormatter('${x:,.0f}'))
ax_alloc.set_ylabel('Allocation (USD)')
ax_alloc.legend(loc='upper right')
ax_alloc.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()
