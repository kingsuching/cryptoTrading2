# %% [markdown]
# # Full End-to-End Pipeline

# %%
# ── Google Colab Setup ────────────────────────────────────────────────────────
# This cell is a no-op when running locally.
import sys, os
from pathlib import Path

from js2py_.base import false

_root = next((p for p in [Path(os.getcwd()), *Path(os.getcwd()).parents]
              if p.name == 'cryptoTrading2'), None)
if _root:
    os.chdir(str(_root))
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from tqdm import tqdm
from files.functions import *

# %% [markdown]
# # Set up the Data

# %%
import datetime as dt
dt.datetime.now().year
# pd.read_csv(fullDataPath('BTC'))['time'].max()
# Out:
# 2026

# %%
refetch(f'data/BTC_df.csv')
# Out:
# False

# %%
myCoins = ['AVAX', 'BTC', 'ETH', 'LTC', 'SOL', 'ICP']
myCoins = [i.upper() for i in myCoins]

# %%
for myCoin in tqdm(myCoins):
    if refetch(fullDataPath(myCoin)):
        coinbase_market_analysis_gradient(myCoin, dataPath='data', plotPath='plots')
        cn = newspaper_sentiment_pipeline(myCoin, newspaper_path=f'newspapers/{myCoin}_newspapers.csv', queries_path='files/queries.txt')
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 60.98it/s]

# %% [markdown]
# ## Train Models

# %%
from files.functions import train_all_models
import warnings
warnings.filterwarnings('ignore')

for myCoin in tqdm(myCoins):
    train_all_models(myCoin, retrain=True)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# ============================================================
#   Training all models for AVAX
# ============================================================
#
# [GBM] starting...
# [GBM] done  —  std_rmse = 0.8836
#
# [SVM] starting...
# [SVM] done  —  std_rmse = 1.2131
#
# [KNN] starting...
# [KNN] done  —  std_rmse = 1.2989
#
# [ARIMA] starting...
# [ARIMA] done  —  std_rmse = 0.7385
#
# [LSTM] starting...
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2252, in <lambda>
#     ('TFT',         lambda: run_tft_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1896, in run_tft_pipeline
#     raise ValueError(f'Not enough sequences for TFT training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2253, in <lambda>
#     ('Transformer', lambda: run_transformer_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1979, in run_transformer_pipeline
#     raise ValueError(f'Not enough sequences for Transformer training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#  17%|█▋        | 1/6 [00:16<01:21, 16.28s/it]
# [LSTM] done  —  std_rmse = 0.6688
#
# [TFT] starting...
# [TFT] FAILED: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
# [Transformer] starting...
# [Transformer] FAILED: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
#
# ============================================================
#   Results for AVAX
# ============================================================
#   LSTM             0.6688
#   ARIMA            0.7385
#   GBM              0.8836
#   SVM              1.2131
#   KNN              1.2989
#   TFT              FAILED
#   Transformer      FAILED
#
# ============================================================
#   Training all models for BTC
# ============================================================
#
# [GBM] starting...
# [GBM] done  —  std_rmse = 1.0087
#
# [SVM] starting...
# [SVM] done  —  std_rmse = 0.6083
#
# [KNN] starting...
# [KNN] done  —  std_rmse = 1.3162
#
# [ARIMA] starting...
# [ARIMA] done  —  std_rmse = 0.5314
#
# [LSTM] starting...
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2252, in <lambda>
#     ('TFT',         lambda: run_tft_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1896, in run_tft_pipeline
#     raise ValueError(f'Not enough sequences for TFT training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2253, in <lambda>
#     ('Transformer', lambda: run_transformer_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1979, in run_transformer_pipeline
#     raise ValueError(f'Not enough sequences for Transformer training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#  33%|███▎      | 2/6 [00:34<01:10, 17.53s/it]
# [LSTM] done  —  std_rmse = 1.0024
#
# [TFT] starting...
# [TFT] FAILED: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
# [Transformer] starting...
# [Transformer] FAILED: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
#
# ============================================================
#   Results for BTC
# ============================================================
#   ARIMA            0.5314
#   SVM              0.6083
#   LSTM             1.0024
#   GBM              1.0087
#   KNN              1.3162
#   TFT              FAILED
#   Transformer      FAILED
#
# ============================================================
#   Training all models for ETH
# ============================================================
#
# [GBM] starting...
# [GBM] done  —  std_rmse = 0.8549
#
# [SVM] starting...
# [SVM] done  —  std_rmse = 0.8316
#
# [KNN] starting...
# [KNN] done  —  std_rmse = 1.9055
#
# [ARIMA] starting...
# [ARIMA] done  —  std_rmse = 0.6162
#
# [LSTM] starting...
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2252, in <lambda>
#     ('TFT',         lambda: run_tft_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1896, in run_tft_pipeline
#     raise ValueError(f'Not enough sequences for TFT training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2253, in <lambda>
#     ('Transformer', lambda: run_transformer_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1979, in run_transformer_pipeline
#     raise ValueError(f'Not enough sequences for Transformer training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#  50%|█████     | 3/6 [00:51<00:52, 17.43s/it]
# [LSTM] done  —  std_rmse = 0.8890
#
# [TFT] starting...
# [TFT] FAILED: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
# [Transformer] starting...
# [Transformer] FAILED: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
#
# ============================================================
#   Results for ETH
# ============================================================
#   ARIMA            0.6162
#   SVM              0.8316
#   GBM              0.8549
#   LSTM             0.8890
#   KNN              1.9055
#   TFT              FAILED
#   Transformer      FAILED
#
# ============================================================
#   Training all models for LTC
# ============================================================
#
# [GBM] starting...
# [GBM] done  —  std_rmse = 1.9714
#
# [SVM] starting...
# [SVM] done  —  std_rmse = 9.0668
#
# [KNN] starting...
# [KNN] done  —  std_rmse = 5.2272
#
# [ARIMA] starting...
# [ARIMA] done  —  std_rmse = 1.0460
#
# [LSTM] starting...
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2252, in <lambda>
#     ('TFT',         lambda: run_tft_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1896, in run_tft_pipeline
#     raise ValueError(f'Not enough sequences for TFT training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2253, in <lambda>
#     ('Transformer', lambda: run_transformer_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1979, in run_transformer_pipeline
#     raise ValueError(f'Not enough sequences for Transformer training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#  67%|██████▋   | 4/6 [01:08<00:34, 17.05s/it]
# [LSTM] done  —  std_rmse = 4.8529
#
# [TFT] starting...
# [TFT] FAILED: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
# [Transformer] starting...
# [Transformer] FAILED: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
#
# ============================================================
#   Results for LTC
# ============================================================
#   ARIMA            1.0460
#   GBM              1.9714
#   LSTM             4.8529
#   KNN              5.2272
#   SVM              9.0668
#   TFT              FAILED
#   Transformer      FAILED
#
# ============================================================
#   Training all models for SOL
# ============================================================
#
# [GBM] starting...
# [GBM] done  —  std_rmse = 0.7488
#
# [SVM] starting...
# [SVM] done  —  std_rmse = 0.6506
#
# [KNN] starting...
# [KNN] done  —  std_rmse = 1.7852
#
# [ARIMA] starting...
# [ARIMA] done  —  std_rmse = 0.5476
#
# [LSTM] starting...
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2252, in <lambda>
#     ('TFT',         lambda: run_tft_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1896, in run_tft_pipeline
#     raise ValueError(f'Not enough sequences for TFT training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2253, in <lambda>
#     ('Transformer', lambda: run_transformer_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1979, in run_transformer_pipeline
#     raise ValueError(f'Not enough sequences for Transformer training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#  83%|████████▎ | 5/6 [01:24<00:16, 16.56s/it]
# [LSTM] done  —  std_rmse = 0.7390
#
# [TFT] starting...
# [TFT] FAILED: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
# [Transformer] starting...
# [Transformer] FAILED: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
#
# ============================================================
#   Results for SOL
# ============================================================
#   ARIMA            0.5476
#   SVM              0.6506
#   LSTM             0.7390
#   GBM              0.7488
#   KNN              1.7852
#   TFT              FAILED
#   Transformer      FAILED
#
# ============================================================
#   Training all models for ICP
# ============================================================
#
# [GBM] starting...
# [GBM] done  —  std_rmse = 1.0581
#
# [SVM] starting...
# [SVM] done  —  std_rmse = 0.6121
#
# [KNN] starting...
# [KNN] done  —  std_rmse = 1.2764
#
# [ARIMA] starting...
# [ARIMA] done  —  std_rmse = 1.3118
#
# [LSTM] starting...
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2252, in <lambda>
#     ('TFT',         lambda: run_tft_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1896, in run_tft_pipeline
#     raise ValueError(f'Not enough sequences for TFT training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
# Traceback (most recent call last):
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2272, in train_all_models
#     out = run()
#           ^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 2253, in <lambda>
#     ('Transformer', lambda: run_transformer_pipeline(coin, number=number)),
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sucheen/Documents/cryptoTrading2/files/functions.py", line 1979, in run_transformer_pipeline
#     raise ValueError(f'Not enough sequences for Transformer training (got {len(X_seq)}, need ≥10). '
# ValueError: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
# 100%|██████████| 6/6 [01:40<00:00, 16.75s/it]
# [LSTM] done  —  std_rmse = 1.6355
#
# [TFT] starting...
# [TFT] FAILED: Not enough sequences for TFT training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
# [Transformer] starting...
# [Transformer] FAILED: Not enough sequences for Transformer training (got 0, need ≥10). Try reducing seq_len or providing more data.
#
#
# ============================================================
#   Results for ICP
# ============================================================
#   SVM              0.6121
#   GBM              1.0581
#   KNN              1.2764
#   ARIMA            1.3118
#   LSTM             1.6355
#   TFT              FAILED
#   Transformer      FAILED

# %% [markdown]
# ## Run Predictions

# %%
predict_matrix('AVAX')
# Out:
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/AVAX/AVAXAVAX_knn_model.pkl'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#              2026-05-30  2026-05-31  2026-06-01  2026-06-02  2026-06-03  \
# Model
# GBM            9.125520    9.123181    9.123181    9.123181    9.123181
# SVM            8.688599    8.651648    8.641439    8.638619    8.637840
# ARIMA          8.830000    8.830000    8.830000    8.830000    8.830000
# TFT            9.720791    9.727832    9.722171    9.716736    9.705202
# Transformer   13.261010   13.432606   13.268054   13.083871   12.890392
# Prophet        7.088200    6.885231    7.030056    6.975336    6.690598
#
#              2026-06-04  2026-06-05
# Model
# GBM            9.123181    9.123181
# SVM            8.637625    8.637565
# ARIMA          8.830000    8.830000
# TFT            9.692270    9.677070
# Transformer   12.725489   12.568252
# Prophet        6.536146    6.558493

# %%
for coin in tqdm(myCoins):
    predictions = predict_matrix(coin)
    if not os.path.exists(f'predictions/{coin}'):
        os.mkdir(f'predictions/{coin}')
    predictions.to_csv(f'predictions/{coin}/{coin}_predictions.csv')
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/AVAX/AVAXAVAX_knn_model.pkl'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#  33%|███▎      | 2/6 [00:00<00:00,  4.55it/s]
#   [predict_matrix] LSTM skipped — 'scaler_method'
#  50%|█████     | 3/6 [00:00<00:00,  4.57it/s]
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ETH/ETHETH_knn_model.pkl'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#  67%|██████▋   | 4/6 [00:00<00:00,  4.60it/s]
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/LTC/LTCLTC_knn_model.pkl'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/SOL/SOLSOL_knn_model.pkl'
#  83%|████████▎ | 5/6 [00:01<00:00,  4.80it/s]
#   [predict_matrix] LSTM skipped — 'scaler_method'
# 100%|██████████| 6/6 [00:01<00:00,  5.43it/s]
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICPICP_knn_model.pkl'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#   [predict_matrix] TFT skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICP_tft_meta.pkl'
#   [predict_matrix] Transformer skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICP_transformer_meta.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICP_prophet_model.pkl'

# %% [markdown]
# ## Portfolio Optimizer

# %% [markdown]
# Compute Ranking based on Standardized RMSE

# %%
rmses = {}
for myCoin in tqdm(myCoins):
    errors = os.listdir(os.path.join('metrics', myCoin))
    for model_rmse in errors:
        model_name = model_rmse.split('_')[0].upper()
        file_path = os.path.join('metrics', myCoin, model_rmse)
        with open(file_path) as f:
            rmses[model_name] = float(f.read())
rmses = pd.Series(rmses)
rmses.rank().sort_values()
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 1118.13it/s]
# PROPHET        1.0
# KNN            2.0
# TRANSFORMER    3.0
# TFT            4.0
# SVM            5.0
# GBM            6.0
# ARIMA          7.0
# LSTM           8.0
# dtype: float64

# %% [markdown]
# ### Portfolio Optimization
#
# **Method:**
# 1. **Ensemble forecast** — for each coin, average the `m` model predictions weighted by `1 / RMSE` (better-calibrated models carry more weight).
# 2. **Daily expected returns** — compare each day's ensemble price to the previous day (or to today's closing price for day 0).
# 3. **Allocation** — solve the long-only max-return problem each day:
#
# $$\max_{\mathbf{w}} \sum_i w_i r_i \quad \text{s.t.} \quad \sum_i w_i \le 1,\; w_i \ge 0$$
#
#    The closed-form solution is *proportional to positive expected returns*: coins with a negative forecast get 0 weight and the corresponding capital stays in cash.
# 4. **Simulation** — compound the portfolio value day-by-day using the weighted return.
#
# > To add more coins, extend `myCoins` at the top of the notebook.

# %%
import numpy as np

# ─────────────────────────────────────────────────────────────────────────────
# USER PARAMETERS
# ─────────────────────────────────────────────────────────────────────────────
PRINCIPAL       = 404.90    # Starting investment in USD
COINS_PORTFOLIO = myCoins   # Coins to include — add more to myCoins at the top
# ─────────────────────────────────────────────────────────────────────────────

# ── Step 1: RMSE-weighted ensemble price forecast per coin ────────────────────
# Lower RMSE → more trustworthy model → higher weight in the ensemble average.
ensemble_prices = {}
current_prices  = {}

for coin in COINS_PORTFOLIO:
    matrix = predict_matrix(coin)
    matrix.index = matrix.index.str.upper()

    coin_rmses = {}
    for fname in os.listdir(f'metrics/{coin}'):
        model_tag = fname.split('_')[0].upper()
        with open(f'metrics/{coin}/{fname}') as fh:
            coin_rmses[model_tag] = float(fh.read())

    rmse_s  = pd.Series(coin_rmses).reindex(matrix.index)
    weights = (1 / rmse_s).fillna(0)
    w_sum   = weights.sum()
    if w_sum == 0:
        weights = pd.Series(1.0 / len(matrix), index=matrix.index)
    else:
        weights /= w_sum

    ensemble_prices[coin] = (
        matrix.astype(float).multiply(weights.values, axis=0).sum(axis=0)
    )

    raw   = pd.read_csv(fullDataPath(coin))
    daily = dataSetup(raw, trainingColPath=TRAINING_COLUMNS,
                      response=RESPONSE_VARIABLE, number=LIMIT)
    current_prices[coin] = float(daily[RESPONSE_VARIABLE].iloc[-1])

ensemble_df = pd.DataFrame(ensemble_prices)

print("Ensemble predicted prices (USD):")
print(ensemble_df.round(2).to_string())
print("\nCurrent prices:", {c: f'${v:,.2f}' for c, v in current_prices.items()})

# ── Step 2: Cumulative returns and optimal exit day per coin ──────────────────
# cum_return[coin][d] = (predicted_price[d] - current_price) / current_price
# We exit each coin on whichever day maximises this cumulative return.
cum_returns_df = pd.DataFrame(index=ensemble_df.index, columns=COINS_PORTFOLIO, dtype=float)
opt_days    = {}   # coin → index of best exit day within the forecast window
opt_returns = {}   # coin → max cumulative return (may be negative → stay in cash)

for coin in COINS_PORTFOLIO:
    cp = current_prices[coin]
    for i, date in enumerate(ensemble_df.index):
        pred = float(ensemble_df[coin].iloc[i])
        cum_returns_df.loc[date, coin] = (pred - cp) / cp if cp != 0 else 0.0
    cum_returns_df[coin] = cum_returns_df[coin].astype(float)
    best_idx          = int(cum_returns_df[coin].values.argmax())
    opt_days[coin]    = best_idx
    opt_returns[coin] = float(cum_returns_df[coin].iloc[best_idx])

print("\nCumulative returns from current price (%):")
print((cum_returns_df.astype(float) * 100).round(3).to_string())

print("\nOptimal exit strategy:")
for coin in COINS_PORTFOLIO:
    d = opt_days[coin]
    print(f"  {coin}: exit day {d + 1} ({ensemble_df.index[d]}), "
          f"max expected return = {opt_returns[coin] * 100:+.2f}%")

# ── Step 3: Allocate based on maximum achievable return per coin ──────────────
# Coins with a negative best-case return get 0 weight — capital stays in cash.
def _allocate(returns_row: np.ndarray) -> np.ndarray:
    pos   = np.maximum(returns_row, 0.0)
    total = pos.sum()
    return pos / total if total > 0 else np.zeros(len(returns_row))

opt_ret_arr = np.array([opt_returns[c] for c in COINS_PORTFOLIO])
alloc_w     = _allocate(opt_ret_arr)

print(f"\nPortfolio allocation:")
for coin, wi in zip(COINS_PORTFOLIO, alloc_w):
    print(f"  {coin}: {wi * 100:.1f}%")
print(f"  Cash: {(1 - alloc_w.sum()) * 100:.1f}%")

# ── Step 4: Simulate — hold each coin until its optimal exit day ──────────────
# On exit day the position is liquidated; freed capital becomes cash.
# Portfolio value is marked-to-market every day using the ensemble forecast.
cash      = PRINCIPAL * float(1 - alloc_w.sum())
holdings  = {coin: PRINCIPAL * float(wi) for coin, wi in zip(COINS_PORTFOLIO, alloc_w)}
buy_price = {coin: current_prices[coin] for coin in COINS_PORTFOLIO}

portfolio_log = []
prev_value    = PRINCIPAL

for i, date in enumerate(ensemble_df.index):
    # Cash out any coin that reaches its optimal exit today
    for coin in COINS_PORTFOLIO:
        if i == opt_days[coin] and holdings[coin] > 0:
            pred        = float(ensemble_df[coin].iloc[i])
            bp          = buy_price[coin]
            sell_return = (pred - bp) / bp if bp != 0 else 0.0
            cash       += holdings[coin] * (1 + sell_return)
            holdings[coin] = 0.0

    # Mark-to-market: current value of each still-held position
    coin_values = {}
    for coin in COINS_PORTFOLIO:
        if holdings[coin] > 0:
            pred    = float(ensemble_df[coin].iloc[i])
            bp      = buy_price[coin]
            cum_ret = (pred - bp) / bp if bp != 0 else 0.0
            coin_values[coin] = holdings[coin] * (1 + cum_ret)
        else:
            coin_values[coin] = 0.0

    portfolio_value = cash + sum(coin_values.values())
    daily_return    = (portfolio_value - prev_value) / prev_value if prev_value != 0 else 0.0
    prev_value      = portfolio_value

    row = {
        'date':            date,
        'portfolio_value': round(portfolio_value, 2),
        'daily_return_%':  round(daily_return * 100, 4),
    }
    for coin in COINS_PORTFOLIO:
        pv = portfolio_value if portfolio_value > 0 else 1
        row[f'{coin}_%'] = round(coin_values[coin] / pv * 100, 2)
    row['cash_%'] = round(cash / portfolio_value * 100, 2) if portfolio_value > 0 else 100.0
    portfolio_log.append(row)

result_df = pd.DataFrame(portfolio_log).set_index('date')

print(f"\n{'Principal':20s}  ${PRINCIPAL:>12,.2f}")
print(f"{'Final portfolio':20s}  ${portfolio_value:>12,.2f}")
print(f"{'Total return':20s}  {((portfolio_value / PRINCIPAL) - 1) * 100:>+11.2f}%")
print()
print(result_df.to_string())
# Out:
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/AVAX/AVAXAVAX_knn_model.pkl'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ETH/ETHETH_knn_model.pkl'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/LTC/LTCLTC_knn_model.pkl'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/SOL/SOLSOL_knn_model.pkl'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#   [predict_matrix] KNN skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICPICP_knn_model.pkl'
#   [predict_matrix] LSTM skipped — 'scaler_method'
#   [predict_matrix] TFT skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICP_tft_meta.pkl'
#   [predict_matrix] Transformer skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICP_transformer_meta.pkl'
#   [predict_matrix] Prophet skipped — [Errno 2] No such file or directory: '/Users/sucheen/Documents/cryptoTrading2/models/ICP/ICP_prophet_model.pkl'
# Ensemble predicted prices (USD):
#              AVAX       BTC      ETH    LTC    SOL   ICP
# 2026-05-30  10.04  68684.59  2015.92  55.39  86.23  2.64
# 2026-05-31  10.07  65164.74  2013.08  55.61  86.24  2.63
# 2026-06-01  10.03  63557.25  2012.23  55.60  85.93  2.63
# 2026-06-02   9.99  67209.96  2011.97  55.50  85.60  2.63
# 2026-06-03   9.94  65431.52  2011.89  55.37  85.27  2.63
# 2026-06-04   9.90  66118.04  2011.87  55.23  84.93  2.63
# 2026-06-05   9.87  61719.10  2011.86  55.06  84.57  2.63
#
# Current prices: {'AVAX': '$8.83', 'BTC': '$73,500.18', 'ETH': '$2,011.70', 'LTC': '$51.89', 'SOL': '$81.93', 'ICP': '$2.64'}
#
# Cumulative returns from current price (%):
#               AVAX     BTC    ETH    LTC    SOL    ICP
# 2026-05-30  13.700  -6.552  0.210  6.748  5.246 -0.209
# 2026-05-31  14.091 -11.341  0.069  7.178  5.265 -0.438
# 2026-06-01  13.637 -13.528  0.026  7.144  4.881 -0.483
# 2026-06-02  13.145  -8.558  0.013  6.959  4.480 -0.470
# 2026-06-03  12.619 -10.978  0.010  6.709  4.075 -0.455
# 2026-06-04  12.166 -10.044  0.008  6.429  3.656 -0.433
# 2026-06-05  11.729 -16.029  0.008  6.117  3.227 -0.416
#
# Optimal exit strategy:
#   AVAX: exit day 2 (2026-05-31), max expected return = +14.09%
#   BTC: exit day 1 (2026-05-30), max expected return = -6.55%
#   ETH: exit day 1 (2026-05-30), max expected return = +0.21%
#   LTC: exit day 2 (2026-05-31), max expected return = +7.18%
#   SOL: exit day 2 (2026-05-31), max expected return = +5.27%
#   ICP: exit day 1 (2026-05-30), max expected return = -0.21%
#
# Portfolio allocation:
#   AVAX: 52.7%
#   BTC: 0.0%
#   ETH: 0.8%
#   LTC: 26.8%
#   SOL: 19.7%
#   ICP: 0.0%
#   Cash: -0.0%
#
# Principal             $      404.90
# Final portfolio       $      446.97
# Total return               +10.39%
#
#             portfolio_value  daily_return_%  AVAX_%  BTC_%  ETH_%  LTC_%  SOL_%  ICP_%  cash_%
# date
# 2026-05-30           445.65         10.0639   54.43    0.0    0.0  26.03  18.83    0.0    0.71
# 2026-05-31           446.97          0.2956    0.00    0.0    0.0   0.00   0.00    0.0  100.00
# 2026-06-01           446.97          0.0000    0.00    0.0    0.0   0.00   0.00    0.0  100.00
# 2026-06-02           446.97          0.0000    0.00    0.0    0.0   0.00   0.00    0.0  100.00
# 2026-06-03           446.97          0.0000    0.00    0.0    0.0   0.00   0.00    0.0  100.00
# 2026-06-04           446.97          0.0000    0.00    0.0    0.0   0.00   0.00    0.0  100.00
# 2026-06-05           446.97          0.0000    0.00    0.0    0.0   0.00   0.00    0.0  100.00

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

fig, (ax_val, ax_alloc) = plt.subplots(
    2, 1, figsize=(13, 9), gridspec_kw={'height_ratios': [3, 2]}
)

# ── Portfolio value over time ─────────────────────────────────────────────────
pv_series   = [PRINCIPAL] + result_df['portfolio_value'].tolist()
date_labels = ['Now'] + result_df.index.tolist()
x           = range(len(pv_series))

ax_val.plot(x, pv_series, marker='o', linewidth=2.5, color='#2196F3', zorder=3)
ax_val.fill_between(x, PRINCIPAL, pv_series,
                    where=[v >= PRINCIPAL for v in pv_series],
                    color='#4CAF50', alpha=0.25, label='Gain')
ax_val.fill_between(x, PRINCIPAL, pv_series,
                    where=[v < PRINCIPAL for v in pv_series],
                    color='#F44336', alpha=0.25, label='Loss')
ax_val.axhline(PRINCIPAL, color='gray', linestyle='--', alpha=0.7,
               label=f'Principal ${PRINCIPAL:,.0f}')
for i, v in enumerate(pv_series):
    ax_val.annotate(f'${v:,.0f}', (i, v),
                    textcoords='offset points', xytext=(0, 10),
                    ha='center', fontsize=8)
ax_val.set_xticks(list(x))
ax_val.set_xticklabels(date_labels, rotation=20, ha='right')
ax_val.yaxis.set_major_formatter(mtick.StrMethodFormatter('${x:,.0f}'))
ax_val.set_ylabel('Portfolio Value (USD)')
ax_val.set_title(
    f'Portfolio Optimization  —  {", ".join(COINS_PORTFOLIO)}  |  Principal: ${PRINCIPAL:,.0f}',
    fontsize=13, pad=10
)
ax_val.legend()
ax_val.grid(True, alpha=0.3)

# ── Daily allocation stacked bar ──────────────────────────────────────────────
alloc_cols = [f'{c}_%' for c in COINS_PORTFOLIO] + ['cash_%']
bar_labels = COINS_PORTFOLIO + ['Cash']
bar_colors = ['#FF9800', '#4CAF50', '#2196F3', '#9C27B0', '#00BCD4', '#F44336', '#795548']
x_pos      = range(len(result_df))
bottom     = np.zeros(len(result_df))

for idx, (col, label) in enumerate(zip(alloc_cols, bar_labels)):
    vals = result_df[col].values
    ax_alloc.bar(x_pos, vals, bottom=bottom, label=label,
                 color=bar_colors[idx % len(bar_colors)], alpha=0.85)
    for j, (v, b) in enumerate(zip(vals, bottom)):
        if v > 5:
            ax_alloc.text(j, b + v / 2, f'{v:.0f}%',
                          ha='center', va='center',
                          fontsize=9, fontweight='bold', color='white')
    bottom += vals

ax_alloc.set_xticks(list(x_pos))
ax_alloc.set_xticklabels(result_df.index.tolist(), rotation=20, ha='right')
ax_alloc.set_ylabel('Allocation (%)')
ax_alloc.set_ylim(0, 115)
ax_alloc.legend(loc='upper right')
ax_alloc.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()
